# %% [markdown]
# <font size=10>**TASK 3 - ??**</font> <a class="anchor" id='title'></a>
#
# **Bachelor's in Data Science - NOVA IMS (25/26)**
#
# **Project**: *Straining the great southern Melting Pot*
#
# **Group 8**
# - Beatriz Marques 20231605
# - David Carrilho 20231693
# - Duarte Fernandes 20231619
# - Filipe Caçador 20231707
# - Mariana Calais-Pedro 20231641
#
# *«notebook description»*
#
# **Question**: *??*

# %% [markdown]
# <font color='#BFD72' size=6>**TABLE OF CONTENTS**</font> <a class="anchor" id='toc'></a>
# - [1. Imports](#1)
# - [2. Data](#2)
# - [3. ???](#3)
#     - [3.1 Specific Data Preparation](#3_1)
#     - [3.2 Model Implementation](#3_2)
#     - [3.3 Model Evaluation](#3_3)

# %% [markdown]
# # <font color='#BFD72F' size=6>**1. Imports**</font> <a class="anchor" id="1"></a>
#
# [Back to TOC](#toc)

# %%
import warnings
# %load_ext autoreload
# %autoreload 2

warnings.filterwarnings('ignore')

# %%
import sys
import os
import pandas as pd

# Get the absolute path of the source_code folder
source_code_path = os.path.abspath('../source')

# Add the source_code folder to sys.path
if source_code_path not in sys.path:
    sys.path.append(source_code_path)

from my_utils import *
from visualizations import *

# %% [markdown]
# # <font color='#BFD72F' size=6>**2. Data**</font> <a class="anchor" id="2"></a>
#
# [Back to TOC](#toc)

# %%
dataset_original = load_dataset('../data/atlanta_restaurant_slice_2023.csv')

# %%
dataset_original.head()
# Out:
#               title             categoryName  \
# 0      The Optimist       Seafood restaurant
# 1      The Optimist       Seafood restaurant
# 2      The Optimist       Seafood restaurant
# 3      The Optimist       Seafood restaurant
# 4      The Optimist       Seafood restaurant
# ...             ...                      ...
# 53561    L On North  New American restaurant
# 53562    L On North  New American restaurant
# 53563    L On North  New American restaurant
# 53564    L On North  New American restaurant
# 53565    L On North  New American restaurant
#
#                                                  website  \
# 0                 https://www.theoptimistrestaurant.com/
# 1                 https://www.theoptimistrestaurant.com/
# 2                 https://www.theoptimistrestaurant.com/
# 3                 https://www.theoptimistrestaurant.com/
# 4                 https://www.theoptimistrestaurant.com/
# ...                                                  ...
# 53561  https://www.lonnorth.com/?utm_source=google&ut...
# 53562  https://www.lonnorth.com/?utm_source=google&ut...
# 53563  https://www.lonnorth.com/?utm_source=google&ut...
# 53564  https://www.lonnorth.com/?utm_source=google&ut...
# 53565  https://www.lonnorth.com/?utm_source=google&ut...
#
#                                                      url  reviewsCount  stars  \
# 0      https://www.google.com/maps/place/The+Optimist...          3349    5.0
# 1      https://www.google.com/maps/place/The+Optimist...          3349    5.0
# 2      https://www.google.com/maps/place/The+Optimist...          3349    5.0
# 3      https://www.google.com/maps/place/The+Optimist...          3349    5.0
# 4      https://www.google.com/maps/place/The+Optimist...          3349    5.0
# ...                                                  ...           ...    ...
# 53561  https://www.google.com/maps/place/L+On+North/@...           449    5.0
# 53562  https://www.google.com/maps/place/L+On+North/@...           449    5.0
# 53563  https://www.google.com/maps/place/L+On+North/@...           449    5.0
# 53564  https://www.google.com/maps/place/L+On+North/@...           449    5.0
# 53565  https://www.google.com/maps/place/L+On+North/@...           449    5.0
#
#                                                     text
# 0      One word amazing!! The red fish,  halibut,  fr...
# 1      First time here and the food is great and the ...
# 2      I recently had the pleasure of dining at Optim...
# 3      Beautiful atmosphere and delicious food. All o...
# 4      We had a wonderful dinner at the Optimist. Our...
# ...                                                  ...
# 53561  Friday night dinner was Chicken Francaise. Jor...
# 53562                 Great dinner.... Yay  Jordan!!!!!!
# 53563  Jordan was our server and he was fantastic! Gr...
# 53564  Jordan was an amazing server!  Great delicious...
# 53565  Great food and service.   Well spaced tables a...
#
# [53566 rows x 7 columns]

# %%
dataset_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53566 entries, 0 to 53565
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         53566 non-null  object
#  1   categoryName  53566 non-null  object
#  2   website       50600 non-null  object
#  3   url           53566 non-null  object
#  4   reviewsCount  53566 non-null  int64
#  5   stars         53566 non-null  float64
#  6   text          53566 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 2.9+ MB

# %% [markdown]
# | 🏷️ **Column Name** | 📝 **Description** |
# |:-------------------|:-------------------|
# |**title** | Name of the restaurant |
# |**categoryName** | Labels that describe the restaurant's cuisine type |
# |**website** | URL of the restaurant's webpage |
# |**url** | URL of the restaurant's Google Maps page |
# |**reviewsCount** | Total number of reviews for the restaurant at the time of scraping |
# |**stars** | Customer rating (1 to 5) |
# |**text** | Text of the review |

# %%
dataset = dataset_original.copy()

# %% [markdown]
# # <font color='#BFD72F' size=6>**3. ??**</font> <a class="anchor" id="3"></a>
#
# [Back to TOC](#toc)

# %% [markdown]
# ## <font color='#BFD72F' size=6>3.1 Specific Data Preparation</font> <a class="anchor" id="3_1"></a>
#
# [Back to TOC](#toc)

# %% [markdown]
# ## <font color='#BFD72F' size=6>3.2 Model Implementation</font> <a class="anchor" id="3_2"></a>
#
# [Back to TOC](#toc)

# %% [markdown]
# ## <font color='#BFD72F' size=6>3.3 Model Evaluation</font> <a class="anchor" id="3_3"></a>
#
# [Back to TOC](#toc)
